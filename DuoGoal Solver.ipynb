# %% [markdown]
# # DuoGoal Solver
#
# Documentacao executavel do projeto. **Toda a logica financeira vive no pacote `duogoal_app`** — este notebook apenas importa e demonstra, sem reimplementar nada. A app Streamlit (`app.py`) e os testes (`tests/`) consomem exatamente o mesmo pacote, entao os resultados sao identicos por construcao.

# %% [markdown]
# ### 1 - Imports
#
# Todas as funcoes vem da API publica do pacote, re-exportada em `duogoal_app/__init__.py`.

# %%
from duogoal_app import (
    SolverInputs,
    avaliar_tempo_total,
    calcular_fronteira,
    grid_search,
    inputs_padrao,
    inputs_to_dict,
    montar_resumo,
    resolver_duas_metas,
    simular_duas_metas,
    taxa_mensal_equivalente,
    validar_entradas,
)
from duogoal_app.charts import grafico_fronteira, grafico_heatmap, grafico_saldos

# %% [markdown]
# ### 2 - Entradas do usuario (EDITE AQUI)
#
# O cenario padrao vem de `inputs_padrao()`. Para personalizar, monte um `SolverInputs` proprio com os mesmos campos.

# %%
inputs = inputs_padrao()
inputs_to_dict(inputs)

# %% [markdown]
# ### 3 - Conversao de taxa (mensal) e validacoes
#
# `validar_entradas` converte a taxa anual para a mensal equivalente (ou repassa a mensal direta) e rejeita entradas invalidas com `ValueError`.

# %%
taxa_mensal = validar_entradas(inputs)
f"Taxa mensal equivalente: {taxa_mensal * 100:.4f}%"

# %% [markdown]
# ### 4 - Simulacao com transferencia de aporte (core)
#
# `simular_duas_metas` evolui os saldos mes a mes. Quando uma meta e atingida, o aporte dela migra automaticamente para a outra (pivo de aporte). Aqui um exemplo com divisao 50/50 dos aportes.

# %%
t1, t2, traj = simular_duas_metas(
    i=taxa_mensal,
    c1=inputs.capital_meta1,
    c2=inputs.capital_meta2,
    ax1=inputs.aporte_extra_total / 2,
    ax2=inputs.aporte_extra_total / 2,
    a1=inputs.aporte_mensal_total / 2,
    a2=inputs.aporte_mensal_total / 2,
    m1=inputs.meta1,
    m2=inputs.meta2,
    max_meses=inputs.max_meses,
)
t1, t2

# %% [markdown]
# ### 5 - Funcao objetivo (tempo total) e avaliacao em grid
#
# O objetivo e minimizar `max(t1, t2)`. `grid_search` varre as combinacoes de `a1` (aporte mensal na Meta 1) e `Ax1` (aporte extra na Meta 1) e devolve o melhor ponto e as grades de tempo.

# %%
melhor, a1_grid, ax1_grid, t_grid, t1_grid, t2_grid = grid_search(
    i=taxa_mensal,
    c1=inputs.capital_meta1,
    c2=inputs.capital_meta2,
    ax_total=inputs.aporte_extra_total,
    a_total=inputs.aporte_mensal_total,
    m1=inputs.meta1,
    m2=inputs.meta2,
    max_meses=inputs.max_meses,
    na=inputs.resolucao_aporte_mensal,
    nx=inputs.resolucao_aporte_extra,
)
melhor

# %% [markdown]
# ### 6 - Otimizacao: grid coarse + refino local
#
# `resolver_duas_metas` encadeia tudo: validacao, grid coarse, refino local iterativo, trajetoria no otimo, fronteira e resumo. E a mesma chamada que a app Streamlit faz.

# %%
resultados = resolver_duas_metas(inputs)
resultados.melhor

# %% [markdown]
# ### 7 - Trajetoria no otimo (para plot principal)
#
# Repare na coluna `aporte1`/`aporte2`: quando a primeira meta e atingida, o aporte dela aparece somado na outra.

# %%
resultados.trajetoria.tail(10)

# %% [markdown]
# ### 8 - Plot 1: Evolucao dos saldos (hover rico)

# %%
grafico_saldos(resultados)

# %% [markdown]
# ### 9 - Plot 2 (opcional): Heatmap do tempo total em funcao de (a1, Ax1)

# %%
grafico_heatmap(resultados)

# %% [markdown]
# ### 10 - Plot 3 (opcional): Curva (fronteira) "melhor tempo vs a1" com Ax1 otimo por a1

# %%
grafico_fronteira(resultados)

# %% [markdown]
# ### 11 - Resumo final (com checagens)
#
# As checagens ao final garantem que a alocacao otima distribui exatamente o total disponivel.

# %%
display(resultados.resumo)
print("Tempos:", resultados.tempos)
print("Alocacao:", resultados.alocacao)
print("Datas:", resultados.datas)

assert resultados.alocacao["a1"] + resultados.alocacao["a2"] == inputs.aporte_mensal_total
assert round(resultados.alocacao["Ax1"] + resultados.alocacao["Ax2"], 8) == inputs.aporte_extra_total
